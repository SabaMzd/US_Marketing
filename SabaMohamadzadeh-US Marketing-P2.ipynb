# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv ('E:/Machine learning/Analysis of DataSet/Marketing Analysis/Market.csv')
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
split_point = 13948

data1 = data.iloc[:split_point]
df1 = pd.DataFrame(data1)
df1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
df1.tail()
# Out:
#       Index       Date         Open         High          Low        Close  \
# 13943   NYA  5/24/2021  16375.00000  16508.51953  16375.00000  16464.68945
# 13944   NYA  5/25/2021  16464.68945  16525.81055  16375.15039  16390.18945
# 13945   NYA  5/26/2021  16390.18945  16466.33984  16388.32031  16451.96094
# 13946   NYA  5/27/2021  16451.96094  16546.35938  16451.96094  16531.94922
# 13947   NYA  5/28/2021  16531.94922  16588.68945  16531.94922  16555.66016
#
#          Adj Close        Volume
# 13943  16464.68945  2.947400e+09
# 13944  16390.18945  3.420870e+09
# 13945  16451.96094  3.674490e+09
# 13946  16531.94922  5.201110e+09
# 13947  16555.66016  4.199270e+09

# %%
df2= round(df1)
df2
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 0      0.000000e+00
# 1      0.000000e+00
# 2      0.000000e+00
# 3      0.000000e+00
# ...

# %%
df2.sort_values(by=["Date"])
df2
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 0      0.000000e+00
# 1      0.000000e+00
# 2      0.000000e+00
# 3      0.000000e+00
# ...

# %%
df2.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13947.000000  13946.000000  13945.000000  13944.000000  13938.000000
# mean    4452.144834   4469.313495   4434.260739   4453.026033   4455.093916
# std     4074.832916   4094.959937   4052.814928   4075.484621   4075.457549
# min      348.000000    348.000000    348.000000    348.000000    348.000000
# 25%      655.000000    655.000000    655.000000    655.000000    656.000000
# 50%     2632.000000   2632.000000   2632.000000   2632.000000   2633.000000
# 75%     7339.500000   7376.500000   7278.000000   7339.750000   7342.750000
# max    16590.000000  16686.000000  16532.000000  16590.000000  16590.000000
#
#              Volume
# count  1.394700e+04
# mean   1.215565e+09
# std    1.834155e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.681975e+09
# max    1.145623e+10

# %%
print ("\n show the missing values of DataFrame: \n\n" , df2.isnull().sum())
# Out:
#  show the missing values of DataFrame:
#
#  Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# Volume        1
# dtype: int64

# %%
df3=df2.dropna()
df3
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 0      0.000000e+00
# 1      0.000000e+00
# 2      0.000000e+00
# 3      0.000000e+00
# ...

# %%
print ("\n show the missing values of DataFrame: \n\n" , df3.isnull().sum())
# Out:
#  show the missing values of DataFrame:
#
#  Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
plt.scatter(df3["Open"] , df3["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("Open" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
###### for analyse this part I use the last video on the website #########

Noise = df3 [(df3["Adj Close"]> 5000) & (df3 ["Open"]<2000)]
Noise
# Out:
#     Index       Date   Open   High    Low  Close  Adj Close  Volume
# 831   NYA  5/29/1969  612.0  612.0  612.0  612.0     6111.0     0.0

# %%
Noise1= df3[df3["Adj Close"]>5000]
Noise1
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close  \
# 831     NYA  5/29/1969    612.0    612.0    612.0    612.0     6111.0
# 7932    NYA   7/3/1997   5051.0   5051.0   5051.0   5051.0     5051.0
# 7933    NYA   7/7/1997   5028.0   5028.0   5028.0   5028.0     5028.0
# 7934    NYA   7/8/1997   5059.0   5059.0   5059.0   5059.0     5059.0
# 7935    NYA   7/9/1997   5002.0   5002.0   5002.0   5002.0     5002.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 831    0.000000e+00
# 7932   0.000000e+00
# 7933   0.000000e+00
# 7934   0.000000e+00
# ...

# %%
Noise2 = df3 [(df3["Adj Close"]< 2000) & (df3 ["Open"]>5000)]
Noise2
# Out:
#     Index       Date    Open   High    Low  Close  Adj Close  Volume
# 852   NYA  6/30/1969  5722.0  572.0  572.0  572.0      572.0     0.0

# %%
Noise3= df3[df3["Open"]>5000]
Noise3
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close  \
# 852     NYA  6/30/1969   5722.0    572.0    572.0    572.0      572.0
# 7932    NYA   7/3/1997   5051.0   5051.0   5051.0   5051.0     5051.0
# 7933    NYA   7/7/1997   5028.0   5028.0   5028.0   5028.0     5028.0
# 7934    NYA   7/8/1997   5059.0   5059.0   5059.0   5059.0     5059.0
# 7935    NYA   7/9/1997   5002.0   5002.0   5002.0   5002.0     5002.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 852    0.000000e+00
# 7932   0.000000e+00
# 7933   0.000000e+00
# 7934   0.000000e+00
# ...

# %%
df3.drop(index=[831,852] , inplace=True)
df3
# Out:
# C:\Users\SabaPC\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# ...

# %%
plt.scatter(df3["High"] , df3["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("High" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
Noise4 = df3 [df3 ["High"]>5900]
Noise4
# Out:
#       Index       Date     Open     High      Low    Close  Adj Close  \
# 829     NYA  5/27/1969    612.0   6124.0    612.0    612.0      612.0
# 833     NYA   6/3/1969    607.0   6066.0    607.0    607.0      607.0
# 8107    NYA  3/16/1998   5942.0   5942.0   5942.0   5942.0     5942.0
# 8108    NYA  3/17/1998   5954.0   5954.0   5954.0   5954.0     5954.0
# 8109    NYA  3/18/1998   5981.0   5981.0   5981.0   5981.0     5981.0
# ...     ...        ...      ...      ...      ...      ...        ...
# 13943   NYA  5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA  5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA  5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA  5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA  5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 829    0.000000e+00
# 833    0.000000e+00
# 8107   0.000000e+00
# 8108   0.000000e+00
# ...

# %%
df3.drop(index=[829,833] , inplace=True)
df3
# Out:
# C:\Users\SabaPC\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# ...

# %%
plt.scatter(df3["Low"] , df3["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("low" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
plt.scatter(df3["Close"] , df3["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("Close" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
plt.scatter(df3["Volume"] , df3["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("Volume" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
### Volume > 0.99
high = df3 ["Volume"].nlargest(5)
high
# Out:
# 10768    1.145623e+10
# 11162    1.061781e+10
# 10752    1.008269e+10
# 13862    9.878040e+09
# 10798    9.495900e+09
# Name: Volume, dtype: float64

# %%
df4 = df3 [df3["Volume"]< 1.008269e+10]
df4
# Out:
#       Index        Date     Open     High      Low    Close  Adj Close  \
# 0       NYA  12/31/1965    529.0    529.0    529.0    529.0      529.0
# 1       NYA    1/3/1966    527.0    527.0    527.0    527.0      527.0
# 2       NYA    1/4/1966    528.0    528.0    528.0    528.0      528.0
# 3       NYA    1/5/1966    531.0    531.0    531.0    531.0      531.0
# 4       NYA    1/6/1966    532.0    532.0    532.0    532.0      532.0
# ...     ...         ...      ...      ...      ...      ...        ...
# 13943   NYA   5/24/2021  16375.0  16509.0  16375.0  16465.0    16465.0
# 13944   NYA   5/25/2021  16465.0  16526.0  16375.0  16390.0    16390.0
# 13945   NYA   5/26/2021  16390.0  16466.0  16388.0  16452.0    16452.0
# 13946   NYA   5/27/2021  16452.0  16546.0  16452.0  16532.0    16532.0
# 13947   NYA   5/28/2021  16532.0  16589.0  16532.0  16556.0    16556.0
#
#              Volume
# 0      0.000000e+00
# 1      0.000000e+00
# 2      0.000000e+00
# 3      0.000000e+00
# ...

# %%
plt.scatter(df4["Volume"] , df4["Adj Close"])
plt.title("Market Analysis" , fontsize=15)
plt.xlabel("Volume" , fontsize=15)
plt.ylabel("Adj Close" , fontsize=15)
#plt.xticks (rotation=90)
plt.grid()
plt.show()

# %%
df4['Date']=pd.to_datetime(df4['Date'])
# Out:
# C:\Users\SabaPC\AppData\Local\Temp/ipykernel_12432/414399670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Date']=pd.to_datetime(df4['Date'])

# %%
plt.plot(df4['Date'],df4['Adj Close'])
plt.title("Date Vs Adj Close")
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.grid()
plt.show()

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
########## with noise ##########
plt.plot(df1['Date'],df1['Adj Close'])                 
plt.title("Date Vs Adj Close")
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.grid()
plt.show()
